# %%
from splitdata  import split_dataset
import pandas as pd

# %%
df = pd.read_csv('../data/Rectrain.csv')

# %%
df_train, df_test, groundTruth= split_dataset(df, 0.8)
# Out:
# /home/agnieszka/NAUKA/Studia/SEM VII/SR/SystemRekomendacyjny/trivago-RecSys-Challenge-2019/splitdata.py:32: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   df_test_label.to_csv('../data/reference.csv')

# %%
df_test.head(15).tail(5)
# Out:
#                user_id     session_id   timestamp  step  \
# 12756513  XI9W70AM4A2E  49fbcccb30f40  1541476182    11
# 12756514  XJU3EN88E88X  dc52a1e8c459a  1541505439     1
# 12756515  XK9Q5KDFWUO8  c039590a248a1  1541468709     1
# 12756516  XN7BVE3ZYOUQ  59f9c54ef3bb0  1541530339     1
# 12756517  XN7BVE3ZYOUQ  59f9c54ef3bb0  1541530339     2
#
#                      action_type        reference platform              city  \
# 12756513  interaction item image           103501       JP      Tokyo, Japan
# 12756514  search for destination  Lonavala, India       IN   Lonavala, India
# 12756515           clickout item              NaN       US     Belek, Turkey
# 12756516  interaction item image          5838026       IN  Ahmedabad, India
# 12756517  interaction item image          5838026       IN  Ahmedabad, India
#
#            device current_filters  \
# 12756513  desktop             NaN
# 12756514   mobile             NaN
# 12756515   mobile             NaN
# 12756516  desktop             NaN
# 12756517  desktop             NaN
#
#                                                 impressions  \
# 12756513                                                NaN
# 12756514                                                NaN
# 12756515  6694076|6160412|908005|1256006|37745|1167790|2...
# 12756516                                                NaN
# 12756517                                                NaN
#
#                                                      prices
# 12756513                                                NaN
# 12756514                                                NaN
# 12756515  341|190|372|514|268|172|161|325|149|899|254|26...
# 12756516                                                NaN
# 12756517                                                NaN

# %%
groundTruth.head(15).tail(5)
# Out:
#                user_id     session_id   timestamp  step  \
# 12756513  XI9W70AM4A2E  49fbcccb30f40  1541476182    11
# 12756514  XJU3EN88E88X  dc52a1e8c459a  1541505439     1
# 12756515  XK9Q5KDFWUO8  c039590a248a1  1541468709     1
# 12756516  XN7BVE3ZYOUQ  59f9c54ef3bb0  1541530339     1
# 12756517  XN7BVE3ZYOUQ  59f9c54ef3bb0  1541530339     2
#
#                      action_type        reference platform              city  \
# 12756513  interaction item image           103501       JP      Tokyo, Japan
# 12756514  search for destination  Lonavala, India       IN   Lonavala, India
# 12756515           clickout item          6694076       US     Belek, Turkey
# 12756516  interaction item image          5838026       IN  Ahmedabad, India
# 12756517  interaction item image          5838026       IN  Ahmedabad, India
#
#            device current_filters  \
# 12756513  desktop             NaN
# 12756514   mobile             NaN
# 12756515   mobile             NaN
# 12756516  desktop             NaN
# 12756517  desktop             NaN
#
#                                                 impressions  \
# 12756513                                                NaN
# 12756514                                                NaN
# 12756515  6694076|6160412|908005|1256006|37745|1167790|2...
# 12756516                                                NaN
# 12756517                                                NaN
#
#                                                      prices
# 12756513                                                NaN
# 12756514                                                NaN
# 12756515  341|190|372|514|268|172|161|325|149|899|254|26...
# 12756516                                                NaN
# 12756517                                                NaN
