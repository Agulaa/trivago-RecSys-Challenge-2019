# %%
import pandas as pd

# %%
df_test = pd.read_csv("../../data/test.csv")

# %%
groundTruth = pd.read_csv("../../data/groundTruth.csv")

# %%
test = df_test[df_test.action_type=="clickout item"][:3]

# %%
groundTruth.head(15).tail(5)
# Out:
#     Unnamed: 0       user_id     session_id   timestamp  step  \
# 10    12755488  XUT4D4LB0YYM  b4ce7d1a34b54  1541509544    11
# 11    12755489  XUT4D4LB0YYM  b4ce7d1a34b54  1541509544    12
# 12    12755490  XUT4D4LB0YYM  b4ce7d1a34b54  1541509592    13
# 13    12755491  XUT4D4LB0YYM  b4ce7d1a34b54  1541509611    14
# 14    12755492  XUT4D4LB0YYM  b4ce7d1a34b54  1541509639    15
#
#                 action_type reference platform             city   device  \
# 10         filter selection    4 Star       DE  Berlin, Germany  desktop
# 11         filter selection    5 Star       DE  Berlin, Germany  desktop
# 12   interaction item deals      5558       DE  Berlin, Germany  desktop
# 13  interaction item rating      5558       DE  Berlin, Germany  desktop
# 14   interaction item deals    132784       DE  Berlin, Germany  desktop
#
#                                  current_filters impressions prices
# 10  5 Star|Hotel|Motel|Resort|Hostal (ES)|4 Star         NaN    NaN
# ...

# %%
test
# Out:
#     Unnamed: 0       user_id     session_id   timestamp  step    action_type  \
# 71    12755549  XUXGAESM2V94  1c72f36b6e465  1541504736     1  clickout item
# 84    12755562  XV5O797KTSPT  fddf7a1a16dbf  1541523235     1  clickout item
# 85    12755563  XVFM46K7ZSL0  d4749fe329176  1541480281     1  clickout item
#
#    reference platform                  city  device current_filters  \
# 71   3168560       ES        Segovia, Spain  mobile             NaN
# 84       NaN       CZ       Vienna, Austria  mobile             NaN
# 85   2674674       MX  Chignahuapan, Mexico  mobile             NaN
#
#                                           impressions  \
# 71  6273996|40302|40094|3168560|154558|931561|4043...
# 84  4053208|2297952|35542|1551005|1698675|7790600|...
# 85  2550910|8462690|5818804|2675406|2685801|267467...
#
#                                                prices
# 71  200|127|110|184|79|45|99|80|190|190|180|98|134...
# ...

# %%
test['impressions']=test['impressions'].apply(lambda x : x.split('|'))

# %%
test
# Out:
#     Unnamed: 0       user_id     session_id   timestamp  step    action_type  \
# 71    12755549  XUXGAESM2V94  1c72f36b6e465  1541504736     1  clickout item
# 84    12755562  XV5O797KTSPT  fddf7a1a16dbf  1541523235     1  clickout item
# 85    12755563  XVFM46K7ZSL0  d4749fe329176  1541480281     1  clickout item
#
#    reference platform                  city  device current_filters  \
# 71   3168560       ES        Segovia, Spain  mobile             NaN
# 84       NaN       CZ       Vienna, Austria  mobile             NaN
# 85   2674674       MX  Chignahuapan, Mexico  mobile             NaN
#
#                                           impressions  \
# 71  [6273996, 40302, 40094, 3168560, 154558, 93156...
# 84  [4053208, 2297952, 35542, 1551005, 1698675, 77...
# 85  [2550910, 8462690, 5818804, 2675406, 2685801, ...
#
#                                                prices
# 71  200|127|110|184|79|45|99|80|190|190|180|98|134...
# ...
